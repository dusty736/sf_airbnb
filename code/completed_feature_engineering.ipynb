# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# Unlimited columns
pd.options.display.max_columns = None

# %% [markdown]
# ## Read in data with engineered features

# %%
# Data path
data_path = "../data/ready_for_modeling/training_data.csv"

# read in data
training_data = pd.read_csv(data_path)
# Out:
# /opt/miniconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3155: DtypeWarning: Columns (21) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
training_data.shape
# Out:
# (29200, 221)

# %%
# Get list of features to explore
# y: price
# x: date, review_count, positive_score_mean, negative_score_mean, neutral_score_mean, most_common_review_cluster
# average_comment_length, review_frequency, holiday_False_ holiday_True, available, maximum_nights_x,
# minimum_nights_x, host_response_time, host_is_superhose, host_neighborhood, host_listings_count, 
# host_total_listings_count, host_has_profile_pic, host_identity_verified, neighourhood_cleansed, propery_type,
# room_type, accommodates, bedrooms, beds, minimum_nights_y, maximum_nights_y, review_scores_rating, 
# review_scores_cleanliness, review_scores_checkin, review_scores_communication, review_scores_location
# review_scores_value, calculated_host_listings_count_entire_homes, 
training_data.head()
# Out:
#    Unnamed: 0  listing_id        date  price  review_count  word_clean_use  \
# 0           0      338849  2021-08-04   59.0             3        0.333333
# 1           1      338849  2021-08-05   59.0             3        0.333333
# 2           2      338849  2021-08-06   59.0             3        0.333333
# 3           3      338849  2021-08-07   59.0             3        0.333333
# 4           4      338849  2021-08-08   59.0             3        0.333333
#
#    word_place_use  word_stay_use  word_would_use  word_nice_use  \
# 0        0.333333       0.666667             0.0            0.0
# 1        0.333333       0.666667             0.0            0.0
# 2        0.333333       0.666667             0.0            0.0
# 3        0.333333       0.666667             0.0            0.0
# 4        0.333333       0.666667             0.0            0.0
#
#    word_great_use  word_easy_use  word_host_use  word_location_use  \
# ...

# %%
# Function for plotting binary dummy variables and price response
def binary_plotting(df, dep_var, indep_var='price'):
    """Creates plot of response variable (price by default) against engineered binary variables
    
    """
    
    binary_plot = plt.plot()
    
    return(binary_plot)

# %%
# Function for plotting binary dummy variables and price response
def continuous_plotting(df, dep_var, indep_var):
    """Creates plot of response variable (price by default) against engineered continuous variables
    
    """
    
    continuous_plot = plt.plot()
    
    return(continuous_plot)
